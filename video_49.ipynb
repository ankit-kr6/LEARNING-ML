# %% [markdown]
# <a href="https://colab.research.google.com/github/ankit-kr6/LEARNING-ML/blob/main/video_49.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !kaggle datasets download -d tann22u/placement-dataset
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/tann22u/placement-dataset
# License(s): unknown
# placement-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile
with zipfile.ZipFile('placement-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('/content')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'],df['package'])

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,model.predict(x_train),color='red')

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
r2_score(y_test,model.predict(x_test))
# Out:
# 0.8260368883156534

# %%
y_pred=model.predict(x_test)

# %%
y_test.values
# Out:
# array([1.86, 4.09, 3.  , 2.72, 1.87, 2.19, 4.02, 4.43, 2.66, 3.16, 2.74,
#        2.99, 4.03, 3.14, 2.56, 3.79, 3.76, 2.08, 3.12, 2.17, 3.44, 2.2 ,
#        2.21, 3.52, 3.39, 2.72, 3.13, 3.42, 3.02, 3.33, 3.24, 2.46, 3.34,
#        3.16, 3.89, 3.44, 2.18, 2.73, 3.49, 2.26])

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
print("R2",r2_score(y_test,y_pred))
r2=r2_score(y_test,y_pred)
# Out:
# MAE 0.213609191917611
# MSE 0.07422369922943975
# RMSE 0.2724402672686983
# R2 0.8260368883156534

# %%
#adjusted R2 score
1-(1-r2)*(len(y_train)-1)/(len(y_train)-x_train.shape[1]-1)
# Out:
# 0.8249358559632208
